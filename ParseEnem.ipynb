# %%
# %pip install --upgrade pymupdf PyPDF2
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pymupdf in /home/alicia/.local/lib/python3.10/site-packages (1.25.2)
# Requirement already satisfied: PyPDF2 in /home/alicia/.local/lib/python3.10/site-packages (3.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from PyPDF2 import PdfReader
import re,fitz
import pandas as pd
import os

# %%
ocr = False
if ocr:
    from tempfile import TemporaryDirectory
    import pytesseract
    from pdf2image import convert_from_path
    from PIL import Image

# %%
#CHANGE FILENAME TO THE NEW ONE
FILENAME = 'ProvasSemImagem/ENEM_2021_P1_CAD_11_DIA_2_LARANJA_LEDOR.pdf'
OUTNAME = 'Data/ENEM_2021_P1_CAD_11_DIA_2_LARANJA_LEDOR.csv'

# %%
class EnemAutomata:
    def __init__(self):
        self.state = 0
        self.question = {}
        self.state_dict = {
            0:'header',
            1:'body',
            'A':'alternative A',
            'B':'alternative B',
            'C':'alternative C',
            'D':'alternative D',
            'E':'alternative E',
            'R':'Essay'
        }
    def clear_memory(self):
        self.state = 0
        self.question = {}
        
    def letter_state(self,current_state,next_state,part):
        if part.strip() != next_state and part.strip() != next_state.lower()+'.':
            if current_state not in self.question:
                self.question[current_state] =''
            self.question[current_state]+=(part.strip('\n')+' ').replace('  ',' ')
        else:
            self.state = next_state
        
    def read(self,part):
        #final state
        if self.state=='E' and (re.search('questão [\d]+',part.lower()) or re.search('ENDOFENEM',part) 
                              or re.search('LC -',part) or re.search('CH -',part) or
                              re.search('\*.*\*',part) or re.search('instruções para a redação',part.lower())):
            ret = self.question.copy()
            self.clear_memory()
            return ret
        elif re.search('\*.*\*',part.lower()) and self.state == 'R':
            ret = self.question.copy()
            self.clear_memory()
            return ret
        
        if not part:
            return False
        elif re.search('questão [\d]+',part.lower()) and self.state == 0:
            self.question['question'] = part.strip()
            self.state = 1
        elif (re.search('instruções para a redação',part.lower()) or re.search('PROPOSTA DE REDAÇÃO',part)) and self.state == 0:
            self.question['question'] = 'redação'
            self.question['body'] = ''
            self.question['A'] = ''
            self.question['B'] = ''
            self.question['C'] = ''
            self.question['D'] = ''
            self.question['E'] = ''
            self.state = 'R'
        elif self.state =='R':
            self.question['body']+=(part.strip('\n')+' ').replace('  ',' ')
        elif self.state == 1 and (part.strip() != 'A' and part.strip() != 'a.'):
            if 'body' not in self.question:
                self.question['body'] = ''
            self.question['body']+=(part.strip('\n')+' ').replace('  ',' ')
        elif self.state==1:
            self.state = 'A'
        elif self.state != 0 and self.state != 1:
            self.letter_state(self.state,chr(ord(self.state)+1),part)
        return False

# %%
class OCRAutomata:
    def __init__(self):
        self.state = 0
        self.question = {}
        self.state_dict = {
            0:'header',
            1:'body',
            'A':'alternative A',
            'B':'alternative B',
            'C':'alternative C',
            'D':'alternative D',
            'E':'alternative E',
            'R':'Essay'
        }
    def clear_memory(self):
        self.state = 0
        self.question = {}
        self.question['question'] = ''
        self.question['body']=''
        self.question['A'] = None
        self.question['B'] = None
        self.question['C'] = None
        self.question['D'] = None
        self.question['E'] = None
        
    def read(self,part):
        #final state
        if self.state==1 and (re.search('questão [\d]+',part.lower()) or re.search('ENDOFENEM',part) 
                              or re.search('LC -',part) or re.search('CH -',part) or
                              re.search('\*.*\*',part) or re.search('instruções para a redação',part.lower())):
            ret = self.question.copy()
            self.clear_memory()
            return ret
        elif re.search('\*.*\*',part.lower()) and self.state == 'R':
            ret = self.question.copy()
            self.clear_memory()
            return ret
        if not part:
            return False
        elif re.search('questão [\d]+',part.lower()) and self.state == 0:
            self.question['question'] = re.search('questão [\d]+',part.lower()).group()
            self.state = 1
        elif (re.search('instruções para a redação',part.lower()) or re.search('PROPOSTA DE REDAÇÃO',part)) and self.state == 0:
            self.question['question'] = 'redação'
            self.question['body'] = ''
            self.question['A'] = None
            self.question['B'] = None
            self.question['C'] = None
            self.question['D'] = None
            self.question['E'] = None
            self.state = 'R'
        elif self.state =='R':
            self.question['body']+=(part.strip('\n')+' ').replace('  ',' ')
        elif self.state == 1:
            if 'body' not in self.question:
                self.question['body'] = ''
            self.question['body']+=(part.strip('\n')+' ').replace('  ',' ')
        return False

# %%
class PhysicalEnemParser:
    def __init__(self,enem_object,engine='pypdf2'):
        self.enem_object = enem_object
        self.engine=engine
        parts = []
        if engine=='pymupdf':
            for page_num in range(1,len(enem_object)):
                page = enem_object[page_num]
                image_list = page.get_images(full=True)
                to_remove = []
                for image in image_list:
                    bbox = page.get_image_bbox(image)
                    tb = page.get_textbox(bbox)
                    to_remove.extend(tb.split('\n'))
                page_text = page.get_text().split('\n')
                for text in page_text:
                    if text not in to_remove:
                        parts.append(text)
        if engine =='pypdf2':
            def visitor_body(text, cm, tm, fontDict, fontSize):
                parts.append(text.replace('[supressão de texto]','[...]'))

            for page in enem_object.pages:
                page.extract_text(visitor_text=visitor_body)
            parts.append('ENDOFENEM')
        #LINUX only
        if engine =='OCR':
            language_config = r'-l por --psm 1'
            # Path of the Input pdf
            PDF_file = enem_object
            
            # Store all the pages of the PDF in a variable
            image_file_list = []
            
            with TemporaryDirectory() as tempdir:
                # Create a temporary directory to hold our temporary images.
                pdf_pages = convert_from_path(PDF_file, 500)
                
                # Iterate through all the pages stored above
                for page_enumeration, page in enumerate(pdf_pages, start=1):        
                    # Create a file name to store the image
                    filename = f"{tempdir}\page_{page_enumeration:03}.jpg"
                    # Save the image of the page in system
                    page.save(filename, "JPEG")
                    image_file_list.append(filename)
                parsed = ''
                # Iterate from 1 to total number of pages
                for image_file in image_file_list:
                # Recognize the text as string in image using pytesserct
                    text = str(((pytesseract.image_to_string(Image.open(image_file),config=language_config))))
                    parsed+=text
                parts = parsed.split('\n')
        self.parts=parts

    def parse_questions(self):
        self.automata = EnemAutomata()
        if self.engine=='OCR':
            self.automata = OCRAutomata()
        questions=[]
        for part in self.parts:
            accept = self.automata.read(part)
            while accept:
                questions.append(accept)
                print('q:', accept)
                accept = self.automata.read(part)
        return questions

# %%
files = list(os.listdir('2023'))
for fileno in files:
    FILENAME = '2023/'+fileno
    OUTNAME = 'Data/'+fileno.strip('.pdf')+'.csv'
    enem = PdfReader(FILENAME)
    parser = PhysicalEnemParser(enem,engine='pypdf2')
    questions = parser.parse_questions()
    df = pd.DataFrame(questions)
    essay_instructions = df.loc[df['question']=='redação','body']
    if not essay_instructions.empty:
        essay_instructions = essay_instructions.iloc[0]
        try:
            df.loc[df['question']=='redação','body'] = re.sub(r'PROPOSTA DE REDAÇÃO.*?(?!(TEXTO))','',essay_instructions) + re.search(r'PROPOSTA DE REDAÇÃO.*?(?=TEXTO)',essay_instructions).group(0)
        except:
            pass
    for column in df.columns:
        df[column] = df[column].apply(lambda x: x.replace('\t',' ').replace('  ',' ').strip())
    df.to_csv(OUTNAME,index=False)
# Out:
# parte:
# parte:
# parte: PROVA DE LINGUAGENS, CÓDIGOS E SUAS TECNOLOGIAS E REDAÇÃO
#
# parte: PROVA DE CIÊNCIAS HUMANAS E SUAS TECNOLOGIAS
# parte:
# parte:
# parte:
#
# parte: As estrelas se miram namoradas.EXAME NACIONAL DO ENSINO MÉDIO
# parte:
# parte:
# parte:
#
# parte: 1º DIA
#
# parte: CADERNO
#
# parte: 9
#
# parte: LARANJA
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte: 2017
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
#
# parte: Ministério
#
# parte: da Educação
# parte:
# parte: LEDOR
#
# parte: LEIA ATENTAMENTE AS INSTRUÇÕES SEGUINTES:
#
# parte: 1.
# parte:   Este CADERNO DE QUESTÕES contém 90 questões numeradas de 01 a 90 e a Proposta de Redação,
#
# parte: dispostas da seguinte maneira:
#
# parte: a) questões de número 01 a 45, relativas à área de Linguagens, Códigos e suas Tecnologias;
#
# parte: b) Proposta de Redação;
#
# parte: c) questões de número 46 a 90, relativas à área de Ciências Humanas e suas Tecnologias.
# parte:
#
# parte:  ATENÇÃO
# parte: : as questões de 01 a 05 são relativas à língua estrangeira. Você deverá responder apenas
#
# parte: às questões relativas à língua estrangeira (inglês ou espanhol) escolhida no ato de sua inscrição.
# parte:
#
# parte: 2.
# parte: Conﬁra se a quantidade e a ordem das questões do seu CADERNO DE QUESTÕES estão de acordo
# parte: com as instruções anteriores. Caso o caderno esteja incompleto, tenha defeito ou apresente qualquer
#
# parte: divergência, comunique ao aplicador da sala para que ele tome as providências cabíveis.
# parte:
#
# parte: 3.
# parte:  Para cada uma das questões objetivas, são apresentadas 5 opções. Apenas uma responde corretamente à questão.
# parte:
#
# parte: 4.
# parte: O tempo disponível para estas provas é de
# parte: cinco horas e trinta minutos
# parte: .
# parte:
#
# parte: 5.
# parte: Reserve os 30 minutos ﬁnais para marcar seu
# parte:
#
# parte: CARTÃO-RESPOSTA . Os rascunhos e as marcações
#
# parte: assinaladas no CADERNO DE QUESTÕES não serão considerados na avaliação.
# parte:
#
# parte: 6.
# parte: Somente serão corrigidas as redações transcritas na FOLHA DE REDAÇÃO.
# parte:
#
# parte: 7.
# parte: Quando terminar as provas, acene para chamar o aplicador e entregue este CADERNO DE QUESTÕES e o CARTÃO-RESPOSTA/FOLHA DE REDAÇÃO.
# parte:
#
# parte: 8.
# parte: Você poderá deixar o local de prova somente após decorridas duas horas do início da aplicação e
# parte:
#
# parte: poderá levar seu CADERNO DE QUESTÕES ao deixar em deﬁnitivo a sala de prova nos 30 minutos
# parte:
#
# parte: que antecedem o término das provas.
# parte: ATENÇÃO
# parte: : transcreva no espaço apropriado do seu CARTÃO-RESPOSTA,
# parte:
#
# parte: com sua caligraﬁa usual, considerando as letras maiúsculas e minúsculas, a seguinte frase:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
#
# parte: *LE0175LA1*
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte: LC - 1º dia | Caderno 9 - LARANJA - Página 2
# parte:
# parte:
#
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte: LINGUAGENS, CÓDIGOS E SUAS
#
# parte: TECNOLOGIAS
#
# parte: Questões de 01 a 45Questões de 01 a 05 (opção inglês)
#
# parte: QUESTÃO 01
# parte:
#
# parte: One of the things that made an incredible impression
# parte:
#
# parte: on me in the ﬁlm was Frida’s comfort in and celebration
#
# parte: of her own unique beauty. She didn’t try to ﬁt into
#
# parte: conventional ideas or images about womanhood or
#
# parte: what makes someone or something beautiful. Instead,
#
# parte: she fully inhabited her own unique gifts, not particularly caring what other people thought. She was magnetic and beautiful in her own right. She painted for years, not to be
# parte: a commercial success or to be discovered, but to express
# parte:
#
# parte: her own inner pain, joy, family, love and culture. She
#
# parte: absolutely and resolutely was who she was. The trueness of her own unique vision and her ability to stand ﬁrmly in
#
# parte: her own truth was what made her successful in the end.
#
# parte: A autora desse comentário sobre o ﬁlme
# parte: Frida
# parte:  mostra-se
#
# parte: impressionada com o fato de a pintora
# parte:
#
# parte: A
# parte:  ter uma aparência exótica.
# parte:
#
# parte: B
# parte:  vender bem a sua imagem.
# parte:
#
# parte: C
# parte:  ter grande poder de sedução.
# parte:
#
# parte: D
# parte:  assumir sua beleza singular.
# parte:
#
# parte: E
# parte:  recriar-se por meio da pintura.
# parte:
#
# parte: QUESTÃO 02
#
# parte: British Government to Recruit Teens as Next
#
# parte: Generation of Spies
# parte:
#
# parte: In the 50 years since the ﬁrst James Bond movie
#
# parte: created a lasting impression of a British secret agent,
#
# parte: a completely different character is about to emerge.
#
# parte: Britain’s intelligence agencies are to recruit their next generation of cyber spies by harnessing the talents of the
# parte: “Xbox generation”.
# parte:
#
# parte: In an expansion of a pilot program, Foreign Secretary
#
# parte: William Hague announced Thursday that up to 100
#
# parte: 18-year-olds will be given the chance to train for a
#
# parte: career in Britain’s secret services. The move to recruit
# parte:
# parte:
#
# parte: school-leavers marks a break with the past, when agencies mainly drew their staff from among university graduates.
#
# parte: “Young people are the key to our country’s future
#
# parte: success, just as they were during the War”, Hague said.
#
# parte: “Today we are not at war, but I see evidence every day of
#
# parte: deliberate, organized attacks against intellectual property and government networks in the United Kingdom.”
#
# parte: The new recruitment program, called the Single
#
# parte: Intelligence Account apprenticeship scheme will enable students with suitable qualiﬁcations in science, technology or engineering, to spend two years learning about communications, security and engineering through formal
#
# parte: education, technical training and work placements.
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte: Segundo informações veiculadas pela NBC News, a
# parte:
#
# parte: geração digital já tem seu espaço conquistado nas
#
# parte: agências britânicas de inteligência. O governo britânico
#
# parte: decidiu que
# parte:
#
# parte: A
# parte:  enfrentará a guerra vigente e deliberada contra a
#
# parte: propriedade intelectual no Reino Unido.
# parte:
#
# parte: B
# parte:  abandonará a política de contratação de universitários
#
# parte: como agentes secretos.
# parte:
#
# parte: C
# parte:  recrutará jovens jogadores de Xbox como ciberespiões
#
# parte: das agências de inteligência.
# parte:
#
# parte: D
# parte:  implantará um esquema de capacitação de
#
# parte: adolescentes para atuarem como agentes secretos.
# parte:
#
# parte: E
# parte:  anunciará os nomes dos jovens a serem contratados
#
# parte: pelas agências de inteligência.
# parte:
#
# parte: QUESTÃO 03
# parte:
# parte:
#
# parte: Descrição da propaganda:
# parte: Cartaz com a imagem de
#
# parte: um parafuso e uma ruela caídos no chão em meio a
#
# parte: uma pequena poça de um líquido escuro e viscoso.
# parte: Acima da imagem, o texto: “Take your car just anyplace for an oil change, and you may regret it down the road.”
# parte:
#
# parte: Nesse texto publicitário são utilizados recursos verbais e
#
# parte: não verbais para transmitir a mensagem. Ao associar os
#
# parte: termos
# parte: anyplace
# parte:  e
# parte: regret
# parte:  à imagem do texto, constata-se
#
# parte: que o tema da propaganda é a importância da
# parte:
#
# parte: A
# parte:  preservação do meio ambiente.
# parte:
#
# parte: B
# parte:  manutenção do motor.
# parte:
#
# parte: C
# parte:  escolha da empresa certa.
# parte:
#
# parte: D
# parte:  consistência do produto.
# parte:
#
# parte: E
# parte:  conservação  do carro.
# parte: *LE0175LA2*
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte: LC - 1º dia | Caderno 9 - LARANJA - Página 3
# parte:
# parte:
#
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte: QUESTÃO 04
#
# parte: Letters
# parte:
#
# parte: Children and Guns
# parte:
#
# parte: Published: May 7, 2013 To the Editor: Re “Girl’s Death by Gunshot Is Rejected as
#
# parte: Symbol” (news article, May 6):
#
# parte: I ﬁnd it abhorrent that the people of Burkesville, Ky., are not
#
# parte: willing to learn a lesson from the tragic shooting of a 2-year-
#
# parte: old girl by her 5-year-old brother. I am not judging their
#
# parte: lifestyle of introducing guns to children at a young age, but I
#
# parte: do feel that it’s irresponsible not to practice basic safety with
#
# parte: anything potentially lethal — guns, knives, ﬁre and so on.
#
# parte: How can anyone justify leaving guns lying around, unlocked and possibly loaded, in a home with two young children?
# parte:
# parte:
#
# parte: I wish the family of the victim comfort during this difﬁcult
# parte: time, but to dismiss this as a simple accident leaves open
# parte:
#
# parte: the potential for many more such “accidents” to occur.
# parte:
# parte:
#
# parte: I hope this doesn’t have to happen several more times for
# parte:
#
# parte: legislators to realize that something needs to be changed.
# parte:
#
# parte: EMILY LOUBATON
#
# parte: Brooklyn, May 6, 2013
#
# parte: No que diz respeito à tragédia ocorrida em Burkesville, a
# parte:
#
# parte: autora da carta enviada ao
# parte: The New York Times
# parte:  busca
# parte:
#
# parte: A
# parte:  reconhecer o acidente noticiado como um fato isolado.
# parte:
#
# parte: B
# parte:  responsabilizar o irmão da vítima pelo incidente
#
# parte: ocorrido.
# parte:
#
# parte: C
# parte:  apresentar versão diferente da notícia publicada
#
# parte: pelo jornal.
# parte:
#
# parte: D
# parte:  expor sua indignação com a negligência de portadores
#
# parte: de armas.
# parte:
#
# parte: E
# parte:  reforçar a necessidade de proibição do uso de armas
#
# parte: por crianças.
# parte:
#
# parte: QUESTÃO 05
#
# parte: Israel Travel Guide
# parte:
#
# parte: Israel
# parte:  has
# parte: always been a standout destination.
#
# parte: From the days of prophets to the modern day nomad this
#
# parte: tiny slice of land on the eastern Mediteranean has long
#
# parte: attracted visitors. While some arrive in the ‘Holy Land’ on
#
# parte: a spiritual quest, many others are on cultural tours, beach holidays and eco-tourism trips. Weeding through Israel’s convoluted history is both exhilarating and exhausting.
# parte: There are crumbling temples, ruined cities, abandoned
# parte: forts and hundreds of places associated with the Bible. And while a sense of adventure is required, most sites are safe and easily accessible. Most of all, Israel is about its incredibly diverse population. Jews come from all over
#
# parte: the world to live here, while about 20% of the population
#
# parte: is Muslim. Politics are hard to get away from in Israel as everyone has an opinion on how to move the country forward — with a ready ear you’re sure to hear opinions from every side o
# parte: f the political spectru m.
# parte:
# parte:
# parte:
# parte:
# parte: Antes de viaja r, turistas geralmente buscam informações
#
# parte: sobre o local para onde pretendem ir. O trecho do guia de
# parte:
#
# parte: viagens de Israel
# parte:
#
# parte: A
# parte:  descreve a história desse local para que turistas
#
# parte: valorizem seus costumes milenares.
# parte:
#
# parte: B
# parte:  informa hábitos religiosos para auxiliar turistas a
#
# parte: entenderem as diferenças culturais.
# parte:
#
# parte: C
# parte:  divulga os principais pontos turísticos para ajudar
#
# parte: turistas a planejarem sua viagem.
# parte:
#
# parte: D
# parte:  recomenda medidas de segurança para alertar
#
# parte: turistas sobre possíveis riscos locais.
# parte:
#
# parte: E
# parte:  apresenta aspectos gerais da cultura do país para
#
# parte: continuar a atrair turistas estrangeiro s.
# parte:
# parte:
# parte:
#
# parte: LINGUAGENS, CÓDIGOS E SUAS
#
# parte: TECNOLOGIAS
#
# parte: Questões de 01 a 45
#
# parte: Questões de 01 a 05 (opção espanhol)
#
# parte: QUESTÃO 01
#
# parte: El carpintero
# parte:
#
# parte: Orlando Goicoechea reconoce las maderas por el
# parte:
#
# parte: olor, de qué árboles vienen, qué edad tienen, y oliéndolas
#
# parte: sabe si fueron cortadas a tiempo o a destiempo y les
# parte: adivina los posibles contratiempos.
#
# parte: Al cabo de tantos años de trabajo, Orlando se ha dado
# parte:
#
# parte: el lujo de comprarse un video, y ve una película tras otra.
# parte:
#
# parte: No sabía que eras loco por cine le dice el vecino.
#
# parte: Y Orlando le explica que no, que a él ni le va ni le
#
# parte: viene, pero gracias al video puede detener las películas
#
# parte: para estudiar los muebles.
#
# parte: No conto de Galeano, a expressão
# parte: ni le va ni le viene
# parte:
#
# parte: encerra uma opinião a respeito de cinema que
# parte:
#
# parte: A
# parte:  desconstrói a ideia central do conto sobre a
#
# parte: importância das atividades de lazer.
# parte:
#
# parte: B
# parte:  contradiz a percepção que o narrador tem em relação
# parte:
#
# parte: à proﬁssão exercida por Orlando.
# parte:
#
# parte: C
# parte:  revela o descaso do narrador com relação ao ofício
#
# parte: desempenhado por Orlando.
# parte:
#
# parte: D
# parte:  reforça a impressão do vizinho de que Orlando
# parte:
#
# parte: gostava de ﬁlmes.
# parte:
#
# parte: E
# parte:  evidencia a extrema devoção do carpinteiro ao
#
# parte: seu ofício.
# parte: *LE0175LA3*
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte: LC - 1º dia | Caderno 9 - LARANJA - Página 4
# parte:
# parte:
#
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte: QUESTÃO 02
#
# parte: El virus del papiloma humano (HPV) también es
#
# parte: un problema de hombres
# parte:
#
# parte: Para algunos hombres, el virus del papiloma humano
# parte:
#
# parte: (HPV) es algo muy lejano. Se olvidan de que ellos también
#
# parte: se infectan y de que, al contagiarnos, nos están regalando un pasaporte mágico para el cáncer cérvico-uterino —
# parte:
#
# parte: segunda causa de muerte entre las mujeres de México
# parte:
#
# parte: —; incluso me ha tocado escuchar en boca de algunos de
# parte: ellos que “sólo se trata de una infeccioncita”. Pues bien, el HPV también es un problema de hombres, no sólo porque propaga la infección entre la población femenina,
#
# parte: sino también porque este virus produce otros problemas
# parte:
#
# parte: de salud tanto en hombres como en mujeres, incluyendo verrugas genitales y cáncer de boca y garganta que, si bien
# parte:
#
# parte: no son tan conocidos o alarmantes por su cantidad, como
# parte:
#
# parte: otros tipos de cáncer, también constituyen un riesgo. Por
# parte: lo anterior, la Academia Americana de Pediatría decidió enfrentarse al HPV mediante vacunas que se ponen tanto
# parte:
#
# parte: a mujeres como hombres. Los especialistas aﬁrman que
# parte:
#
# parte: la vacuna es más efectiva si se administra antes de que el
# parte: niño se vuelva sexualmente activo, y responde mejor en el organismo de varones entre 9 y 15 años.
# parte:
#
# parte: O texto aborda a temática do HPV. Ao discorrer sobre o
#
# parte: contágio e a prevenção do papiloma humano, a autora
#
# parte: informa aos leitores que esse vírus é
# parte:
#
# parte: A
# parte:  estudado pela Academia Americana de Pediatria por
#
# parte: seus efeitos em crianças.
# parte:
#
# parte: B
# parte:  responsável pelo aumento de casos de câncer na
#
# parte: população jovem mexicana.
# parte:
#
# parte: C
# parte: ignorado pelos homens por se restringir à
#
# parte: população feminina.
# parte:
#
# parte: D
# parte:  combatido por vacinas que devem ser aplicadas tanto
#
# parte: em mulheres quanto em homens.
# parte:
#
# parte: E
# parte:  classiﬁcado como um problema superável pela
# parte:
#
# parte: facilidade com que se enfrenta a infecção.
# parte:
#
# parte: QUESTÃO 03
# parte:
#
# parte: Aquí estoy establecido,
# parte: En los Estados Unidos,
# parte: Diez años pasaron ya,
# parte:
#
# parte: En que crucé de mojado,
#
# parte: Papeles no he arreglado,Sigo siendo un ilegal.
# parte: Tengo mi esposa y mis hijos,
#
# parte: Que me los traje muy chicos,
#
# parte: Y se han olvidado ya,
# parte: De mi México querido,
# parte: Del que yo nunca me olvido,
# parte: Y no puedo regresar.
#
# parte: [...]
#
# parte: Mis hijos no hablan conmigo,Otro idioma han aprendido,Y olvidado el español,Piensan como americanos,
#
# parte: Niegan que son mexicanos,
#
# parte: Aunque tengan mi color.
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte: A letra de canção coloca em cena um dilema por vezes
# parte:
#
# parte: vivenciado por imigrantes. Esse dilema se conﬁgura no
# parte:
#
# parte: sentimento do pai em relação ao(à)
# parte:
#
# parte: A
# parte:  diluição de sua identidade latino-americana, advinda
#
# parte: do contato cotidiano com o outro.
# parte:
#
# parte: B
# parte:  distanciamento dos ﬁlhos, gerado pela apropriação
# parte:
#
# parte: da língua e da cultura do outro.
# parte:
#
# parte: C
# parte:  preconceito étnico-racial sofrido pelos imigrantes
#
# parte: mexicanos no novo país.
# parte:
#
# parte: D
# parte:  desejo de se integrar à nova cultura e de se comunicar
#
# parte: na outra língua.
# parte:
#
# parte: E
# parte:  vergonha perante os ﬁlhos de viver ilegalmente em
# parte:
#
# parte: outro país.
# parte:
#
# parte: QUESTÃO 04
#
# parte: Emotivo encuentro en la universidad pública
# parte:
#
# parte: El entonces mandatario uruguayo recibió el cariño
#
# parte: de sus compatriotas residentes en Nueva York e informó
# parte:
#
# parte: sobre la evolución del país, las políticas de gobierno,
# parte:
#
# parte: los avances y cuentas pendientes. Como en ocasiones
#
# parte: similares, se multiplicaron las muestras de respeto y
# parte: emoción. “Una nación es un formidable sentimiento de un
# parte:
#
# parte: ‘nosotros’”, dijo.
# parte:
#
# parte: Mujica comenzó su discurso relatando lo recogido
#
# parte: de otras experiencias de comunidades en el exilio.
# parte:
#
# parte: “Muchos de ustedes echaron raíces, tienen hijos y no
# parte: pueden cometer la agresión de descuajarle la vida.
#
# parte: Tienen que cargar con esa nostalgia de ser de allá, pero
#
# parte: estar acá”, dijo.
#
# parte: “Estamos metidos en la lucha por mejorar las
#
# parte: circunstancias, con el sueño de que las generaciones que
# parte:
#
# parte: vengan, puedan venir con más soltura, con más apoyo”,
# parte:
#
# parte: dijo el Presidente.
# parte:
#
# parte: Mujica se reﬁrió a algunas críticas que reciben
# parte:
#
# parte: algunas políticas sociales. “Nos acusan de que damos
# parte: sin contrapartida. Nos dicen ‘a la gente no hay que
#
# parte: darle pescado, sino enseñarle a pescar’. Sí — razonó
#
# parte: el Presidente —, pero cuando le afanaste la caña, le afanaste el bote, ¿qué le vas a pedir? Para atrás no
# parte:
#
# parte: arreglamos, arreglamos para adelante.”
#
# parte: No discurso dirigido aos compatriotas radicados em Nova
# parte:
#
# parte: York, o então presidente Mujica expressa o desejo de que
# parte:
#
# parte: os cidadãos que vivem no Uruguai
# parte:
#
# parte: A
# parte:  apoiem as políticas públicas aﬁrmativas.
# parte:
#
# parte: B
# parte:  integrem-se ao processo de globalização.
# parte:
#
# parte: C
# parte:  cultivem o sentimento nacionalista.
# parte:
#
# parte: D
# parte:  ofereçam uma contrapartida à nação.
# parte:
#
# parte: E
# parte:  tenham melhores condições de vida.
# parte: *LE0175LA4*
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte: LC - 1º dia | Caderno 9 - LARANJA - Página 5
# parte:
# parte:
#
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte: QUESTÃO 05
#
# parte: El eclipse
# parte:
#
# parte: Cuando
# parte: Fray Bartolomé Arrazola se sintió perdido
#
# parte: aceptó que ya nada podría salvarlo. La selva poderosa
#
# parte: de Guatemala lo había apresado, implacable y deﬁnitiva. Ante su ignorancia topográﬁca se sentó con tranquilidad
# parte:
#
# parte: a esperar la muerte. Al despertar se encontró rodeado por
#
# parte: un grupo de indígenas de rostro impasible que se disponía
# parte: a sacriﬁcarlo ante un altar, un altar que a Bartolomé le
#
# parte: pareció como el lecho en que descansaría, al ﬁn, de sus
# parte:
#
# parte: temores, de su destino, de sí mismo. Tres años en el país
#
# parte: le habían conferido un mediano dominio de las lenguas
# parte: nativas. Intentó algo. Dijo algunas palabras que fueron comprendidas. Entonces floreció en él una idea que tuvo
#
# parte: por digna de su talento y de su cultura universal y de su
# parte:
#
# parte: arduo conocimiento de Aristóteles. Recordó que para ese día se esperaba un eclipse total de sol. Y dispuso, en lo más íntimo, valerse de aquel conocimiento para engañar
# parte: a sus opresores y salvar la vida. — Si me matáis — les
#
# parte: dijo — puedo hacer que el sol se oscurezca en su altura.
# parte:
# parte:
#
# parte: Los indígenas lo miraron ﬁjamente y Bartolomé sorprendió
# parte:
#
# parte: la incredulidad en sus ojos. Vio que se produjo un pequeño
# parte:
#
# parte: consejo, y esperó conﬁado, no sin cierto desdén.
# parte:
# parte:
#
# parte: Dos horas después el corazón de Fray Bartolomé Arrazola
# parte:
#
# parte: chorreaba su sangre vehemente sobre la piedra de los
# parte:
#
# parte: sacriﬁcios (brillante bajo la opaca luz de un sol eclipsado),
# parte: mientras uno de los indígenas recitaba sin ninguna
# parte: inflexión de voz, sin prisa, una por una las inﬁnitas fechas en que se producirían eclipses solares y lunares, que
#
# parte: los astrónomos de la comunidad maya habían previsto y
# parte:
#
# parte: anotado en sus
# parte: códices sin la valiosa ayuda de Aristóteles.
# parte:
#
# parte: No texto, confrontam-se duas visões de mundo: a da
# parte:
#
# parte: cultura ocidental, representada por Frei Bartolomé
# parte: Arrazola, e a da mítica pré-hispânica, representada pela comunidade indígena maia. Segundo a narrativa,
# parte:
#
# parte: A
# parte:  os catequizadores espanhóis avalizam os saberes
#
# parte: produzidos pelas comunidades indígenas hispano-americanas.
# parte:
#
# parte: B
# parte:  os indígenas da comunidade maia mostram-se
#
# parte: perplexos diante da superioridade do conhecimento aristotélico do frei espanhol.
# parte:
#
# parte: C
# parte:  o catequizador espanhol Arrazola apresenta-se
#
# parte: adaptado às culturas autóctones, ao promover a interlocução entre os conhecimentos aristotélico e indígena.
# parte:
#
# parte: D
# parte:  o episódio representa, de forma neutra, o signiﬁcado
# parte:
#
# parte: do conhecimento ancestral indígena, quando comparado ao conhecimento ocidental.
# parte:
#
# parte: E
# parte:  os conhecimentos acadêmicos de Arrazola são
# parte:
#
# parte: insuﬁcientes para salvá-lo da morte, ante a sabedoria
# parte: astronômica da cultura maia.
# parte:
# parte:
# parte:
# parte:
# parte:
# parte: Questões de 06 a 45
#
# parte: QUESTÃO 06
#
# parte: Romanos usavam redes sociais há
#
# parte: dois mil anos, diz livro
# parte:
#
# parte: Ao tuitar ou comentar embaixo do
# parte: post
# parte:  de um de seus
# parte:
#
# parte: vários amigos no Facebook, você provavelmente se sente
# parte:
#
# parte: privilegiado por viver em um tempo na história em que é possível alcançar de forma imediata uma vasta rede de
#
# parte: contatos por meio de um simples clique no botão “enviar”.
# parte:
#
# parte: Você talvez também reflita sobre como as gerações
# parte:
#
# parte: passadas puderam viver sem mídias sociais, desprovidas
#
# parte: da capacidade de verem e serem vistas, de receber, gerar e interagir com uma imensa carga de informações. Mas o que você talvez não saiba é que os seres humanos usam
#
# parte: ferramentas de interação social há mais de dois mil anos.
# parte:
#
# parte: É o que aﬁrma Tom Standage, autor do livro
# parte: Writing on the
#
# parte: Wall
# parte:  —
# parte: Social Media, The first 2 000 Years
# parte:  (Escrevendo
# parte:
#
# parte: no mural — mídias sociais, os primeiros 2 mil anos, em
# parte: tradução livre).
# parte:
#
# parte: Segundo Standage, Marco Túlio Cícero, ﬁlósofo e
# parte:
#
# parte: político romano, teria sido, junto com outros membros da elite romana, precursor do uso de redes sociais. O autor relata como Cícero usava um escravo, que posteriormente
#
# parte: tornou-se seu escriba, para redigir mensagens em rolos
#
# parte: de papiro que eram enviados a uma espécie de rede de contatos. Estas pessoas, por sua vez, copiavam seu texto,
#
# parte: acrescentavam seus próprios comentários e repassavam
#
# parte: adiante. “Hoje temos computadores e banda larga, mas os romanos tinham escravos e escribas que transmitiam suas
# parte:
#
# parte: mensagens”, disse Standage à BBC Brasil. “Membros
# parte:
#
# parte: da elite romana escreviam entre si constantemente,
#
# parte: comentando sobre as últimas movimentações políticas e
#
# parte: expressando opiniões.”
#
# parte: Além do papiro, outra plataforma comumente utilizada
#
# parte: pelos romanos era uma tábua de cera do tamanho e da forma de um
# parte: tablet
# parte: moderno, em que escreviam recados,
#
# parte: perguntas ou transmitiam os principais pontos da
# parte: acta diurna
# parte:  , um “jornal” exposto diariamente no Fórum de
#
# parte: Roma. Essa tábua, o “iPad da Roma Antiga”, era levada por um mensageiro até o destinatário, que respondia embaixo da mensagem.
#
# parte: Na reportagem, há uma comparação entre tecnologias
#
# parte: de comunicação antigas e atuais. Quanto ao gênero
# parte: mensagem, identiﬁca-se como característica que perdura
# parte:
#
# parte: ao longo dos tempos o(a)
# parte:
#
# parte: A
# parte:  imediatismo das respostas.
# parte:
#
# parte: B
# parte:  compartilhamento de informações.
# parte:
#
# parte: C
# parte:  interferência direta de outros no texto original.
# parte:
#
# parte: D
# parte:  recorrência de seu uso entre membros da elite.
# parte:
#
# parte: E
# parte:  perﬁl social dos envolvidos na troca comunicativa.
# parte: *LE0175LA5*
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte: LC - 1º dia | Caderno 9 - LARANJA - Página 6
# parte:
# parte:
#
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte: QUESTÃO 07
#
# parte: A causa secreta
#
# parte:
# parte: Machado de Assis
#
# parte: Garcia tinha-se chegado ao cadáver, levantara o
#
# parte: lenço e contemplara por alguns instantes as feições
#
# parte: defuntas. Depois, como se a morte espiritualizasse tudo,
#
# parte: inclinou-se e beijou-a na testa. Foi nesse momento que Fortunato chegou à porta. Estacou assombrado; não podia ser o beijo da amizade, podia ser o epílogo de um livro adúltero [...].
#
# parte: Entretanto, Garcia inclinou-se ainda para beijar outra
#
# parte: vez o cadáver, mas então não pôde mais. O beijo rebentou
#
# parte: em soluços, e os olhos não puderam conter as lágrimas,
#
# parte: que vieram em borbotões, lágrimas de amor calado, e
# parte: irremediável desespero. Fortunato, à porta, onde ﬁcara,
# parte:
#
# parte: saboreou tranquilo essa explosão de dor moral que foi
#
# parte: longa, muito longa, deliciosamente longa.
#
# parte: No fragmento, o narrador adota um ponto de vista que
#
# parte: acompanha a perspectiva de Fortunato. O que singulariza
#
# parte: esse procedimento narrativo é o registro do(a)
# parte:
#
# parte: A
# parte:  indignação face à suspeita do adultério da esposa.
# parte:
#
# parte: B
# parte:  tristeza compartilhada pela perda da mulher amada.
# parte:
#
# parte: C
# parte:  espanto diante da demonstração de afeto de Garcia.
# parte:
#
# parte: D
# parte: prazer da personagem em relação ao sofrimento
#
# parte: alheio.
# parte:
#
# parte: E
# parte: superação do ciúme pela comoção decorrente da
#
# parte: morte.
# parte:
#
# parte: QUESTÃO 08
# parte:
#
# parte: Mas assim que penetramos no universo da
# parte: web
# parte: ,
#
# parte: descobrimos que ele constitui não apenas um imenso “território” em expansão acelerada, mas que também
# parte:
#
# parte: oferece inúmeros “mapas”, ﬁltros, seleções para ajudar
# parte:
#
# parte: o navegante a orientar-se. O melhor guia para a
# parte: web
# parte:  é a própria
# parte: web
# parte: . Ainda que seja preciso ter a paciência
# parte:
#
# parte: de explorá-la. Ainda que seja preciso arriscar-se a ﬁcar
# parte:
#
# parte: perdido, aceitar “a perda de tempo” para familiarizar-se com esta terra estranha. Talvez seja preciso ceder por um instante a seu aspecto lúdico para descobrir, no desvio de um
# parte: link
# parte: , os
# parte: sites
# parte:  que mais se aproximam de nossos
# parte:
#
# parte: interesses proﬁssionais ou de nossas paixões e que
# parte:
#
# parte: poderão, portanto, alimentar da melhor maneira possível nossa jornada pessoal.
#
# parte: O usuário iniciante sente-se não raramente desorientado
#
# parte: no oceano de informações e possibilidades disponíveis na rede mundial de computadores. Nesse sentido,
# parte: Pierre Lévy destaca como um dos principais aspectos da
# parte:
#
# parte: internet o(a)
# parte:
#
# parte: A
# parte:  espaço aberto para a aprendizagem.
# parte:
#
# parte: B
# parte:  grande número de ferramentas de pesquisa.
# parte:
#
# parte: C
# parte:  ausência de mapas ou guias explicativos.
# parte:
#
# parte: D
# parte:  inﬁnito número de páginas virtuais.
# parte:
#
# parte: E
# parte:  diﬁcul
# parte: dade de acesso aos
# parte: sites
# parte:  de pesquisa.
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte: QUESTÃO 09
#
# parte: TEXTO I
# parte:
#
# parte: Terezinha de Jesus
#
# parte: De uma queda foi ao chãoAcudiu três cavalheiros
#
# parte: Todos os três de chapéu na mão
#
# parte: O primeiro foi seu pai
#
# parte: O segundo, seu irmãoO terceiro foi aqueleA quem Tereza deu a mão
# parte:
#
# parte: TEXTO II
# parte:
#
# parte: Outra interpretação é feita a partir das condições
#
# parte: sociais daquele tempo. Para a ama e para a criança para
#
# parte: quem cantava a cantiga, a música falava do casamento
#
# parte: como um destino natural na vida da mulher, na sociedade
# parte:
#
# parte: brasileira do século XIX, marcada pelo patriarcalismo. A
# parte: música prepara a moça para o seu destino não apenas
#
# parte: inexorável, mas desejável: o casamento, estabelecendo
#
# parte: uma hierarquia de obediência (pai, irmão mais velho,
#
# parte: marido), de acordo com a época e circunstâncias de sua
#
# parte: vida.
# parte:
#
# parte: O comentário do Texto II sobre o Texto I evoca a
# parte:
#
# parte: mobilização da língua oral que, em determinados contextos,
# parte:
#
# parte: A
# parte:  assegura a existência de pensamentos contrários à
#
# parte: ordem vigente.
# parte:
#
# parte: B
# parte:  mantém a heterogeneidade das formas de relações
#
# parte: sociais.
# parte:
#
# parte: C
# parte:  conserva a influência religiosa sobre certas culturas.
# parte:
#
# parte: D
# parte:  preserva a diversidade cultural e comportamental.
# parte:
#
# parte: E
# parte:  reforça comportamentos e padrões culturais.
# parte:
#
# parte: QUESTÃO 10
#
# parte: Infância
# parte:
#
# parte: Graciliano Ramos
#
# parte: Essas moças tinham o vezo de afirmar o contrário
#
# parte: do que desejavam. Notei
# parte: a
# parte:
# parte: singularidade
# parte:  quando
#
# parte: principiaram a elogiar o meu paletó cor de macaco.
#
# parte: Examinavam-no sérias, achavam o pano e os
#
# parte: aviamentos de qualidade superior, o feitio admirável. Envaideci-me: nunca havia reparado em
# parte: tais vantagens
# parte: . Mas
# parte: os
# parte:
# parte: gabos
# parte:  se prolongaram, trouxeram-me
#
# parte: desconfiança. Percebi afinal que elas zombavam e não me susceptibilizei.
# parte: Longe disso
# parte: : achei curiosa
#
# parte: aquela maneira de falar pelo avesso, diferente das grosserias a que me habituara.
# parte: Em geral
# parte: me diziam com franqueza que a roupa não me assentava no corpo, sobrava nos sovacos.
#
# parte: Por meio de recursos linguísticos, os textos mobilizam
#
# parte: estratégias para introduzir e retomar ideias, promovendo a progressão do tema. No fragmento transcrito, um novo aspecto do tema é introduzido pela expressão
# parte:
#
# parte: A
# parte:  “a singularidade”.
# parte:
#
# parte: B
# parte:  “tais vantagens”.
# parte:
#
# parte: C
# parte:  “os gabos”.
# parte:
#
# parte: D
# parte:  “Longe disso”.
# parte:
#
# parte: E
# parte:  “Em geral”.
# parte: *LE0175LA6*
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte: LC - 1º dia | Caderno 9 - LARANJA - Página 7
# parte:
# parte:
#
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte: QUESTÃO 11
# parte:
# parte:
#
# parte: Descrição do diagrama:
# parte:  No centro do diagrama, a
# parte:
#
# parte: imagem de um homem estilizado, identiﬁcado como
# parte:
#
# parte: “Novo consumidor social”. Em volta, círculos com
#
# parte: as características desse consumidor: “Usa novos canais
# parte: on-line
# parte:   e novas ferramentas de comunicação”,
# parte:
#
# parte: “Conﬁa em conselhos de amigos
# parte: on-line
# parte: , conhecidos e
#
# parte: estranhos”, “Tende a comprar mais
# parte: on-line
# parte:  do que
# parte: off-line
# parte: ”,
#
# parte: “Quer fornecer
# parte: feedback
# parte:   sobre o produto e serviço ao
#
# parte: cliente”, “Deseja uma experiência melhor
# parte: on-line
# parte:   do que
# parte:
#
# parte: off-line
# parte: ”, “Lê e cria avaliações,
# parte: ranking
# parte:   de produtos e
# parte:
#
# parte: posts
# parte:  em
# parte: blogs
# parte:  ”, “Quer suporte para encontrar pessoas
#
# parte: que compartilham da mesma opinião”.
# parte:
#
# parte: O consumidor do século XXI, chamado de novo
# parte:
#
# parte: consumidor social, tende a se comportar de modo diferente do consumidor tradicional. Pela associação das
#
# parte: características apresentadas no diagrama, infere-se que
# parte:
#
# parte: esse novo consumidor sofre influência da
# parte:
#
# parte: A
# parte:  cultura do comércio eletrônico.
# parte:
#
# parte: B
# parte:  busca constante pelo menor preço.
# parte:
#
# parte: C
# parte:  divulgação de informações pelas empresas.
# parte:
#
# parte: D
# parte:  necessidade recorrente de consumo.
# parte:
#
# parte: E
# parte:  postura comum aos consumidores tradicionais.
# parte:
#
# parte: QUESTÃO 12
#
# parte: A língua tupi no Brasil
# parte:
#
# parte: Há 300 anos, morar na vila de São Paulo de
#
# parte: Piratininga (peixe seco, em tupi) era quase sinônimo
#
# parte: de falar língua de índio. Em cada cinco habitantes da cidade, só dois conheciam o português. Por isso, em 1698, o governador da província, Artur de Sá e Meneses, implorou a Portugal que só mandasse padres
#
# parte: que soubessem “a língua geral dos índios”, pois “aquela
#
# parte: gente não se explica em outro idioma”.
#
# parte: Derivado do dialeto de São Vicente, o tupi de
# parte:
#
# parte: São Paulo se desenvolveu e se espalhou no século XVII,
#
# parte: graças ao isolamento geográﬁco da cidade e à atividade
# parte:
#
# parte: pouco cristã dos mamelucos paulistas: as bandeiras, expedições ao sertão em busca de escravos índios. Muitos bandeirantes nem sequer falavam o português
#
# parte: ou se expressavam mal. Domingos Jorge Velho, o
#
# parte: paulista que destruiu o Quilombo dos Palmares em
#
# parte: 1694, foi descrito pelo bispo de Pernambuco como “um
#
# parte: bárbaro que nem falar sabe”. Em suas andanças, essa
#
# parte: gente batizou lugares como Avanhandava (lugar onde o índio corre), Pindamonhangaba (lugar de fazer anzol) e
# parte: Itu (cachoeira). E acabou inventando uma nova língua.
# parte:
#
# parte: “Os escravos dos bandeirantes vinham de mais de
#
# parte: 100 tribos diferentes”, conta o historiador e antropólogo John Monteiro, da Universidade Estadual de Campinas.
# parte: “Isso mudou o tupi paulista, que, além da influência do
# parte:
# parte:
# parte:
# parte:
# parte:
# parte: português, ainda recebia palavras de outros idiomas.”
# parte: O resultado da mistura ﬁcou conhecido como língua geral
# parte:
#
# parte: do sul, uma espécie de tupi facilitado.
#
# parte: O texto trata de aspectos sócio-históricos da formação
#
# parte: linguística nacional. Quanto ao papel do tupi na formação
#
# parte: do português brasileiro, depreende-se que essa língua
#
# parte: indígena
# parte:
#
# parte: A
# parte:  contribuiu efetivamente para o léxico, com nomes
#
# parte: relativos aos traços característicos dos lugares designados.
# parte:
#
# parte: B
# parte:  originou o português falado em São Paulo no século
# parte:
#
# parte: XVII, em cuja base gramatical também está a fala de
# parte: variadas etnias indígenas.
# parte:
#
# parte: C
# parte:  desenvolveu-se sob influência dos trabalhos de
# parte:
#
# parte: catequese dos padres portugueses, vindos de Lisboa.
# parte:
#
# parte: D
# parte:  misturou-se aos falares africanos, em razão das
#
# parte: interações entre portugueses e negros nas investidas contra o Quilombo dos Palmares.
# parte:
#
# parte: E
# parte:  expandiu-se paralelamente ao português falado
#
# parte: pelo colonizador, e juntos originaram a língua dos bandeirantes paulistas.
# parte:
#
# parte: QUESTÃO 13
#
# parte: O farrista
# parte:
#
# parte: Quando o almirante Cabral
# parte:
#
# parte: Pôs as patas no Brasil
# parte: O anjo da guarda dos índiosEstava passeando em Paris.Quando ele voltou de viagemO holandês já está aqui.O anjo respira alegre:“Não faz mal, isto é boa gente,Vou arejar outra vez.”O anjo transpôs a barra,Diz adeus a Pernambuco,Faz barulho, vuco-vuco,Tal e qual o zepelimMas deu um vento no anjo,
#
# parte: Ele perdeu a memória...
#
# parte: E não voltou nunca mais.
#
# parte: A obra de Murilo Mendes situa-se na fase inicial do
#
# parte: Modernismo, cujas propostas estéticas transparecem, no
#
# parte: poema, por um eu lírico que
# parte:
#
# parte: A
# parte:  conﬁg
# parte: ura um ideal de nacionalidade pela integração
#
# parte: regional.
# parte:
#
# parte: B
# parte:  remonta ao colonialismo assente sob um viés
#
# parte: iconoclasta.
# parte:
#
# parte: C
# parte:  repercute as manifestações do sincretismo religioso.
# parte:
#
# parte: D
# parte:  descreve a gênese da formação do povo brasileiro.
# parte:
#
# parte: E
# parte:  promove inovações no repertório linguístico.
# parte: *LE0175LA7*
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte: LC - 1º dia | Caderno 9 - LARANJA - Página 8
# parte:
# parte:
#
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte: QUESTÃO 14
# parte:
#
# parte: PROPAGANDA — O exame dos textos e mensagens
# parte:
#
# parte: de Propaganda revela que ela apresenta posições
# parte:
#
# parte: parciais, que refletem apenas o pensamento de uma
# parte: minoria, como se exprimissem, em vez disso, a convicção de uma população; trata-se, no fundo, de convencer o ouvinte ou o leitor de que, em termos de opinião, está fora do caminho certo, e de induzi-lo a aderir às teses que lhes são apresentadas, por um mecanismo bem conhecido da psicologia social, o do conformismo induzido por pressões do grupo sobre o indivíduo isolado.
#
# parte: De acordo com o texto, as estratégias argumentativas
#
# parte: e o uso da linguagem na produção da propaganda
#
# parte: favorecem a
# parte:
#
# parte: A
# parte:  reflexão da sociedade sobre os produtos anunciados.
# parte:
#
# parte: B
# parte:  difusão do pensamento e das preferências das
#
# parte: grandes massas.
# parte:
#
# parte: C
# parte:  imposição das ideias e posições de grupos especíﬁcos.
# parte:
#
# parte: D
# parte:  decisão consciente do consumidor a respeito de sua
#
# parte: compra.
# parte:
#
# parte: E
# parte:  identiﬁcação dos interesses do responsável pelo
# parte:
#
# parte: produto divulgado.
# parte:
#
# parte: QUESTÃO 15
# parte:
#
# parte: Sítio Gerimum
#
# parte: Este é o meu lugar [...]
#
# parte: Meu Gerimum é com g
#
# parte: Você pode ter estranhadoGerimum em abundânciaAqui era plantado
#
# parte: E com a letra g
#
# parte: Meu lugar foi registrado.
#
# parte: Nos versos de um menino de 12 anos, o emprego da
#
# parte: palavra “Gerimum” grafada com a letra “g” tem por objetivo
# parte:
#
# parte: A
# parte: valorizar usos informais caracterizadores da norma
#
# parte: nacional.
# parte:
#
# parte: B
# parte:  conﬁrmar o uso da norma-padrão em contexto da
# parte:
#
# parte: linguagem poética.
# parte:
#
# parte: C
# parte:  enfatizar um processo recorrente na transformação
#
# parte: da língua portuguesa.
# parte:
#
# parte: D
# parte:  registrar a diversidade étnica e linguística presente no
#
# parte: território brasileiro.
# parte:
#
# parte: E
# parte:  reaﬁrmar discursivamente a forte relação do falante
# parte:
#
# parte: com seu lugar de origem.
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte: QUESTÃO 16
#
# parte: TEXTO I
# parte:
#
# parte: Criatividade em publicidade: teorias e reflexões
# parte:
#
# parte: Resumo: O presente artigo aborda uma questão
#
# parte: primordial na publicidade: a criatividade. Apesar de
#
# parte: aclamada pelos departamentos de criação das agências,
#
# parte: devemos ter a consciência de que nem todo anúncio é,
#
# parte: de fato, criativo. A partir do resgate teórico, no qual os conceitos são tratados à luz da publicidade, busca-se estabelecer a compreensão dos temas. Para elucidar tais questões, é analisada uma campanha impressa da
# parte: marca XXXX. As reflexões apontam que a publicidade
# parte: criativa é essencialmente simples e apresenta uma releitura do cotidiano.
# parte:
#
# parte: TEXTO II
# parte:
# parte:
#
# parte: Descrição da imagem:
# parte:  Em um cartaz, aparece a
#
# parte: seguinte frase: “Ninguém entende melhor de criação do que elas. 13 de maio - Dia das Mães”.
#
# parte: Os dois textos apresentados versam sobre o tema
# parte: criatividade. O Texto I é um resumo de caráter cientíﬁco e o Texto II, uma homenagem promovida por um
# parte: site
# parte:
# parte:
#
# parte: de publicidade. De que maneira o Texto II exempliﬁca
# parte: o conceito de criatividade em publicidade apresentado
# parte: no Texto I?
# parte:
#
# parte: A
# parte:  Fazendo menção ao difícil trabalho das mães em criar
# parte:
#
# parte: seus ﬁlhos.
# parte:
#
# parte: B
# parte:  Promovendo uma leitura simplista do papel materno
# parte:
#
# parte: em seu trabalho de criar os ﬁlhos.
# parte:
#
# parte: C
# parte:  Explorando a polissemia do termo “criação”.
# parte:
#
# parte: D
# parte:  Recorrendo a uma estrutura linguística simples.
# parte:
#
# parte: E
# parte:  Utilizando recursos gráﬁcos diversiﬁcados.
# parte: *LE0175LA8*
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte: LC - 1º dia | Caderno 9 - LARANJA - Página 9
# parte:
# parte:
#
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte: QUESTÃO 17
#
# parte: Textos e hipertextos: procurando o equilíbrio
# parte:
#
# parte: Há um medo por parte dos pais e de alguns
#
# parte: professores de as crianças desaprenderem quando
#
# parte: navegam, medo de elas viciarem, de obterem informação
# parte:
#
# parte: não conﬁável, de elas se isolarem do mundo real, como
# parte: se o computador fosse um agente do mal, um vilão. Esse
#
# parte: medo é reforçado pela mídia, que costuma apresentar o
#
# parte: computador como um agente negativo na aprendizagem
#
# parte: e na socialização dos usuários. Nós sabemos que
#
# parte: ninguém corre o risco de desaprender quando navega, seja em ambientes digitais ou em materiais impressos,
#
# parte: mas é preciso ver o que se está aprendendo e algumas
# parte:
#
# parte: vezes interferir nesse processo a ﬁm de otimizar ou
# parte:
#
# parte: orientar a aprendizagem, mostrando aos usuários outros temas, outros caminhos, outras possibilidades diferentes daquelas que eles encontraram sozinhos ou daquelas
#
# parte: que eles costumam usar. É preciso, algumas vezes,
#
# parte: negociar o uso para que ele não seja exclusivo, uma vez
#
# parte: que há outros meios de comunicação, outros meios de
#
# parte: informação e outras alternativas de lazer. É uma questão de equilibrar e não de culpar.
#
# parte: A autora incentiva o uso da internet pelos estudantes,
#
# parte: ponderando sobre a necessidade de orientação a esse
#
# parte: uso, pois essa tecnologia
# parte:
#
# parte: A
# parte:  está repleta de informações conﬁáveis que constituem
# parte:
#
# parte: fonte única para a aprendizagem dos alunos.
# parte:
#
# parte: B
# parte:  exige dos pais e professores que proíbam seu uso
#
# parte: abusivo para evitar que se torne um vício.
# parte:
#
# parte: C
# parte:  tende a se tornar um agente negativo na aprendizagem
#
# parte: e na socialização de crianças e jovens.
# parte:
#
# parte: D
# parte:  possibilita maior ampliação do conhecimento de
#
# parte: mundo quando a aprendizagem é direcionada.
# parte:
#
# parte: E
# parte:  leva ao isolamento do mundo real e ao uso exclusivo
#
# parte: do computador se a navegação for desmedida.
# parte:
#
# parte: QUESTÃO 18
#
# parte: O mundo revivido
# parte:
#
# parte: Hindemburgo Dobal
#
# parte: Sobre esta casa e as árvores que o tempo
#
# parte: esqueceu de levar. Sobre o curral
#
# parte: de pedra e paz e de outras vacas tristes
#
# parte: chorando a lua e a noite sem bezerros.
#
# parte: Sobre a parede larga deste açude
#
# parte: onde outras cobras verdes se arrastavam,
#
# parte: e pondo o sol nos seus olhos parados
#
# parte: iam colhendo sua safra de sapos.
#
# parte: Sob as constelações do sul que a noite
#
# parte: armava e desarmava: as Três Marias,
#
# parte: o Cruzeiro distante e o Sete-Estrelo.
#
# parte: Sobre este mundo revivido em vão,
#
# parte: a lembrança de primos, de cavalos,
#
# parte: de silêncio perdido para sempre.
# parte:
# parte:
# parte:
# parte:
# parte: No processo de reconstituição do tempo vivido, o eu
#
# parte: lírico projeta um conjunto de imagens cujo lirismo se fundamenta no
# parte:
#
# parte: A
# parte:  inventário das memórias evocadas afetivamente.
# parte:
#
# parte: B
# parte:  reflexo da saudade no desejo de voltar à infância.
# parte:
#
# parte: C
# parte:  sentimento de inadequação com o presente vivido.
# parte:
#
# parte: D
# parte:  ressentimento com as perdas materiais e humanas.
# parte:
#
# parte: E
# parte:  lapso no fluxo temporal dos eventos trazidos à cena.
# parte:
#
# parte: QUESTÃO 19
# parte:
#
# parte:  A ascensão social por meio do esporte mexe com
#
# parte: o imaginário das pessoas, pois em poucos anos um
#
# parte: adolescente pode se tornar milionário caso tenha um bom desempenho esportivo. Muitos meninos de famílias pobres jogam com o objetivo de conseguir dinheiro
# parte: para oferecer uma boa qualidade de vida à família. Isso
# parte: aproximou mais ainda o futebol das camadas mais pobres da sociedade, tornando-o cada vez mais popular.
#
# parte:  Acontece que esses jovens sonham com fama e
#
# parte: dinheiro, enxergando no futebol o único caminho possível para o sucesso. No entanto, eles não sabem da grande
# parte: diﬁculdade que existe no início dessa jornada em que a minoria alcança a carreira proﬁssional. Esses garotos
# parte: abandonam a escola pela ilusão de vencer no futebol, à qual a maioria sucumbe.
# parte:
#
# parte:  O caminho até o proﬁssionalismo acontece por meio
# parte:
#
# parte: de um longo processo seletivo que os jovens têm de percorrer. Caso não seja selecionado, esse atleta poderá ter que abandonar a carreira involuntariamente por falta de uma equipe que o acolha. Alguns podem acabar em subempregos, à margem da sociedade, ou até mesmo em vícios decorrentes desse fracasso e dessa desilusão.
# parte: Isso acontece porque no auge da sua formação escolar
# parte: e na condição juvenil de desenvolvimento, eles não se preparam e não são devidamente orientados para buscar alternativas de experiências mais amplas de ocupação fora e além do futebol.
# parte:
#
# parte: Ao abordar o fato de, no Brasil, muitos jovens depositarem
# parte:
#
# parte: suas esperanças de futuro no futebol, o texto critica o(a)
# parte:
#
# parte: A
# parte:  despreparo dos jogadores de futebol para ajudarem
#
# parte: suas famílias a superar a miséria.
# parte:
#
# parte: B
# parte: garantia de ascensão social dos jovens pela carreira de jogador de futebol.
# parte:
#
# parte: C
# parte: falta de investimento dos clubes para que os atletas
# parte:
#
# parte: possam atuar proﬁssionalmente e viver do futebol.
# parte:
#
# parte: D
# parte: investimento reduzido dos atletas proﬁssionais em
# parte: sua formação escolar, gerando frustração e desilusão
# parte:
#
# parte: proﬁssional no esporte.
# parte:
#
# parte: E
# parte: despreocupação dos sujeitos com uma formação paralela à esportiva, para habilitá-los a atuar em outros setores da vida.
# parte: *LE0175LA9*
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte: LC - 1º dia | Caderno 9 - LARANJA - Página 10
# parte:
# parte:
#
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte: QUESTÃO 20
#
# parte: Declaração de amor
# parte:
#
# parte: Esta é uma conﬁssão de amor: amo a língua portuguesa.
# parte:
#
# parte: Ela não é fácil. Não é maleável. […] A língua portuguesa é
# parte:
#
# parte: um verdadeiro desaﬁo para quem escreve. Sobretudo para
# parte: quem escreve tirando das coisas e das pessoas a primeira
# parte: capa de superﬁcialismo.
# parte:
#
# parte: Às vezes ela reage diante de um pensamento mais
#
# parte: complicado. Às vezes se assusta com o imprevisível de
# parte:
#
# ...
#
# parte: de 1945
#
# parte: caracterizou-se por
# parte:
#
# parte: A
# parte:  reclamar a participação das agremiações partidárias.
# parte:
#
# parte: B
# parte:  apoiar a permanência da ditadura estadonovista.
# parte:
#
# parte: C
# parte:  demandar a conﬁrmação dos direitos trabalhistas.
# parte:
#
# parte: D
# parte:  reivindicar a transição constitucional sob influência
# parte:
#
# parte: do governante.
# parte:
#
# parte: E
# parte:  resgatar a representatividade dos sindicatos sob
#
# parte: controle social.
# parte:
#
# parte: QUESTÃO 82
# parte:
#
# parte: Na
# parte: Gazeta de Notícias
# parte: , em 1892, Machado de Assis
#
# parte: escreve:
#
# parte: O instituto popular, de acordo com o exame da
# parte:
#
# parte: razão, fez da ﬁgura do alferes Xavier o principal dos
#
# parte: inconﬁdentes, e colocou os seus parceiros a meia ração de
# parte: glória. Merecem, decerto, a nossa estima aqueles outros;
#
# parte: eram patriotas. Mas o que se ofereceu a carregar com os
# parte: pecadores de Israel, o que chorou de alegria quando viu
# parte: comutada a pena de morte dos seus companheiros, pena que só ia ser executada nele, o enforcado, o esquartejado,
#
# parte: o decapitado, esse tem de receber o prêmio na proporção
#
# parte: do martírio, e ganhar por todos, visto que pagou por todos.
#
# parte: No processo de transição para a República, a narrativa
# parte:
#
# parte: machadiana sobre a Inconﬁdência Mineira associa
# parte:
#
# parte: A
# parte:  redenção cristã e cultura cívica.
# parte:
#
# parte: B
# parte:  veneração aos santos e radicalismo militar.
# parte:
#
# parte: C
# parte:  apologia aos protestantes e culto ufanista.
# parte:
#
# parte: D
# parte:  tradição messiânica e tendência regionalista.
# parte:
#
# parte: E
# parte:  representação eclesiástica e dogmati smo ideológico.
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte: QUESTÃO 83
# parte:
#
# parte: No período anterior ao golpe militar de 1964, os
#
# parte: documentos episcopais indicavam para os bispos
#
# parte: que o desenvolvimento econômico, e claramente o
#
# parte: desenvolvimento capitalista, orientando-se no sentido
#
# parte: da justa distribuição da riqueza, resolveria o problema da miséria rural e, consequentemente, suprimiria a
#
# parte: possibilidade do proselitismo e da expansão comunista
#
# parte: entre os camponeses. Foi nesse sentido que o golpe de
# parte:
#
# parte: Estado, de 31 de março de 1964, foi acolhido pela Igreja.
# parte:
#
# parte: Em que pesem as divergências no interior do clero após
#
# parte: a instalação da ditadura civil-militar, o posicionamento
#
# parte: mencionado no texto fundamentou-se no entendimento
#
# parte: da hierarquia católica de que o(a)
# parte:
#
# parte: A
# parte:  luta de classes é estimulada pelo livre mercado.
# parte:
#
# parte: B
# parte:  poder oligárquico é limitado pela ação do Exército.
# parte:
#
# parte: C
# parte:  doutrina cristã é beneﬁciada pelo atraso do interior.
# parte:
#
# parte: D
# parte:  espaço político é dominado pelo interesse
#
# parte: empresarial.
# parte:
#
# parte: E
# parte:  manipulação ideológica é favorecida pela privação
#
# parte: material.
# parte:
#
# parte: QUESTÃO 84
# parte:
#
# parte: O conceito de democracia, no pensamento de
#
# parte: Habermas, é construído a partir de uma dimensão
#
# parte: procedimental, calcada no discurso e na deliberação.
#
# parte: A legitimidade democrática exige que o processo de
#
# parte: tomada de decisões políticas ocorra a partir de uma ampla discussão pública, para somente então decidir.
#
# parte: Assim, o caráter deliberativo corresponde a um processo coletivo de ponderação e análise, permeado
#
# parte: pelo discurso, que antecede a decisão.
#
# parte: O conceito de democracia proposto por Jürgen Habermas
#
# parte: pode favorecer processos de inclusão social. De acordo
#
# parte: com o texto, é uma condição para que isso aconteça o(a)
# parte:
#
# parte: A
# parte:  participação direta periódica do cidadão.
# parte:
#
# parte: B
# parte:  debate livre e racional entre cidadãos e Estado.
# parte:
#
# parte: C
# parte:  interlocução entre os poderes governamentais.
# parte:
#
# parte: D
# parte:  eleição de lideranças políticas com mandatos
#
# parte: temporários.
# parte:
#
# parte: E
# parte:  controle do poder político por cidadãos mais
#
# parte: esclarecidos.
# parte: *LE0175LA29*
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte: CH - 1º dia | Caderno 9 - LARANJA - Página 30
# parte:
# parte:
#
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte: QUESTÃO 85
# parte:
#
# parte: Na obra
# parte: Fundamentação da metafísica dos
#
# parte: costumes
# parte: , Immanuel Kant escreve:
# parte:
#
# parte: Uma pessoa vê-se forçada pela necessidade a pedir
#
# parte: dinheiro emprestado. Sabe muito bem que não poderá
#
# parte: pagar, mas vê também que não lhe emprestarão nada se
# parte: não prometer ﬁrmemente pagar em prazo determinado.
# parte:
#
# parte: Sente a tentação de fazer a promessa; mas tem ainda consciência bastante para perguntar a si mesma: não é proibido e contrário ao dever livrar-se de apuros desta
# parte: maneira? Admitindo que se decida a fazê-lo, a sua
# parte: máxima de ação seria: quando julgo estar em apuros
#
# parte: de dinheiro, vou pedi-lo emprestado e prometo pagá-lo,
#
# parte: embora saiba que tal nunca sucederá.
# parte:
#
# parte: De acordo com a moral kantiana, a “falsa promessa de
# parte:
#
# parte: pagamento” representada no texto
# parte:
#
# parte: A
# parte:  assegura que a ação seja aceita por todos a partir da
#
# parte: livre discussão participativa.
# parte:
#
# parte: B
# parte:  garante que os efeitos das ações não destruam a
#
# parte: possibilidade da vida futura na terra.
# parte:
#
# parte: C
# parte:  opõe-se ao princípio de que toda ação do homem
#
# parte: possa valer como norma universal.
# parte:
#
# parte: D
# parte:  materializa-se no entendimento de que os ﬁns da
#
# parte: ação humana podem justiﬁcar os meios.
# parte:
#
# parte: E
# parte:  permite que a ação individual produza a mais ampla
#
# parte: felicidade para as pessoas envolvidas.
# parte:
#
# parte: QUESTÃO 86
# parte:
#
# parte: O terremoto de 8,8 na escala Richter que atingiu a
#
# parte: costa oeste do Chile, em fevereiro, provocou mudanças
# parte:
#
# parte: signiﬁcativas no mapa da região. Segundo uma análise
# parte:
#
# parte: preliminar, toda a cidade de Concepción se deslocou pelo
# parte:
#
# parte: menos três metros para o oeste. Buenos Aires moveu-se
# parte: cerca de 2,5 centímetros para oeste, enquanto Santiago, mais próxima do local do evento, deslocou-se quase 30 centímetros para o oeste-sudoeste. As cidades de
#
# parte: Valparaíso, no Chile, e Mendoza, na Argentina, também
# parte:
#
# parte: tiveram suas posições alteradas signiﬁcativamente
# parte:
#
# parte: (13,4 centímetros e 8,8 centímetros, respectivamente).
#
# parte: No texto, destaca-se um tipo de evento geológico
#
# parte: frequente em determinadas partes da superfície terrestre. Esses eventos estão concentrados em
# parte:
#
# parte: A
# parte:  áreas vulcânicas, onde o material magmático se
#
# parte: eleva, formando cordilheiras.
# parte:
#
# parte: B
# parte:  faixas costeiras, onde o assoalho oceânico recebe
#
# parte: sedimentos, provocando
# parte: tsunamis.
# parte:
#
# parte: C
# parte:  estreitas faixas de intensidade sísmica, no contato das
#
# parte: placas tectônicas, próximas a dobramentos modernos.
# parte:
#
# parte: D
# parte:  escudos cristalinos, onde as rochas são submetidas
#
# parte: aos processos de intemperismo, com alterações
#
# parte: bruscas de temperatura.
# parte:
#
# parte: E
# parte:  áreas de bacias sedimentares antigas, localizadas no
#
# parte: centro das placas tectônicas, em regiões conhecidas como pontos quentes.
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte: QUESTÃO 87
# parte:
# parte:
#
# parte: Descrição do mapa:
# parte:  O mapa indica a distribuição
# parte:
#
# parte: das temperaturas mínimas no Brasil, para o dia 28 de
# parte: agosto de 2014, apresentando os seguintes dados:
# parte:
#
# parte: •
# parte: na Região Norte, a temperatura mínima varia
#
# parte: entre 18 e 24 graus Celsius;
# parte:
#
# parte: •
# parte: na Região Nordeste, a temperatura mínima varia
#
# parte: entre 18 e 24 graus Celsius;
# parte:
#
# parte: •
# parte: na Região Centro-Oeste, a temperatura mínima
# parte:
#
# parte: varia entre 11 e 17 graus Celsius;
#
# parte: •
# parte: na Região Sudeste, a temperatura mínima varia
#
# parte: entre 11 e 20 graus Celsius; e
# parte:
#
# parte: •
# parte: na Região Sul, a temperatura mínima varia entre
#
# parte: 4 e 9 graus Celsius.
# parte:
#
# parte: Descrição do quadro:
# parte:  O quadro indica a umidade
#
# parte: relativa do ar (intervalo médio), por região do país, para o dia 28 de agosto de 2014, apresentando os seguintes dados:
# parte:
#
# parte: • Região Norte, com 60 a 70 por cento de umidade
# parte:
#
# parte: relativa;
# parte:
#
# parte: •
# parte: Região Nordeste, com 90 a 100 por cento de umidade relativa;
# parte:
#
# parte: •
# parte: Região Centro-Oeste, com 55 a 65 por cento de
#
# parte: umidade relativa;
# parte:
#
# parte: • Região Sudeste, com 65 a 75 por cento de
# parte:
#
# parte: umidade relativa;
# parte:
#
# parte: •
# parte: Região Sul, com 90 a 100 por cento de umidade relativa.
#
# parte: No dia em que foram colhidos os dados meteorológicos apresentados, qual fator climático foi determinante para
#
# parte: explicar os índices de umidade relativa do ar nas regiões
# parte:
#
# parte: Nordeste e Sul?
# parte:
#
# parte: A
# parte:  Altitude, que forma barreiras naturais.
# parte:
#
# parte: B
# parte:  Vegetação, que afeta a incidência solar.
# parte:
#
# parte: C
# parte:  Massas de ar, que provocam precipitações.
# parte:
#
# parte: D
# parte:  Correntes marítimas, que atuam na troca de calor.
# parte:
#
# parte: E
# parte:  Continentalidade, que influencia na amplitude
# parte:
#
# parte: da temperatura.
# parte: *LE0175LA30*
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte: CH - 1º dia | Caderno 9 - LARANJA - Página 31
# parte:
# parte:
#
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte: QUESTÃO 88
# parte:
#
# parte: Se, pois, para as coisas que fazemos existe um ﬁm
# parte:
#
# parte: que desejamos por ele mesmo e tudo o mais é desejado
# parte:
#
# parte: no interesse desse ﬁm; evidentemente tal ﬁm será o bem,
# parte:
#
# parte: ou antes, o sumo bem. Mas não terá o conhecimento,
# parte: porventura, grande influência sobre essa vida? Se assim
# parte:
#
# parte: é, esforcemo-nos por determinar, ainda que em linhas gerais apenas, o que seja ele e de qual das ciências ou
#
# parte: faculdades constitui o objeto. Ninguém duvidará de que
#
# parte: o seu estudo pertença à arte mais prestigiosa e que
#
# parte: mais verdadeiramente se pode chamar a arte mestra.
#
# parte: Ora, a política mostra ser dessa natureza, pois é ela que determina quais as ciências que devem ser estudadas
#
# parte: num Estado, quais são as que cada cidadão deve
#
# parte: aprender, e até que ponto; e vemos que até as faculdades
#
# parte: tidas em maior apreço, como a estratégia, a economia e
#
# parte: a retórica, estão sujeitas a ela. Ora, como a política utiliza
#
# parte: as demais ciências e, por outro lado, legisla sobre o que
# parte:
#
# parte: devemos e o que não devemos fazer, a ﬁnalidade dessa
# parte:
#
# parte: ciência deve abranger as das outras, de modo que essa
# parte: ﬁnalidade será o bem humano.
# parte:
#
# parte: Na obra
# parte: Ética a Nicômaco
# parte:  , de Aristóteles, a relação entre
#
# parte: o sumo bem e a organização da
# parte: pólis
# parte:  pressupõe que
# parte:
#
# parte: A
# parte:  o bem dos indivíduos consiste em cada um perseguir
#
# parte: seus interesses.
# parte:
#
# parte: B
# parte:  o sumo bem é dado pela fé de que os deuses são os
#
# parte: portadores da verdade.
# parte:
#
# parte: C
# parte:  a política é a ciência que precede todas as demais na
#
# parte: organização da cidade.
# parte:
#
# parte: D
# parte:  a educação visa formar a consciência de cada pessoa
#
# parte: para agir corretamente.
# parte:
#
# parte: E
# parte:  a democracia protege as atividades políticas
#
# parte: necessárias para o bem comum.
# parte:
#
# parte: QUESTÃO 89
# parte:
#
# parte: O comércio soube extrair um bom proveito da
#
# parte: interatividade própria do meio tecnológico. A possibilidade
# parte:
#
# parte: de se obter um alto desenho do perﬁl de interesses do
# parte:
#
# parte: usuário, que deverá levar às últimas consequências o
#
# parte: princípio da oferta como isca para o desejo consumista,
#
# parte: foi o principal deles.
#
# parte: Do ponto de vista comercial, o avanço das novas
#
# parte: tecnologias, indicado no texto, está associado à
# parte:
#
# parte: A
# parte:  atuação dos consumidores como ﬁscalizadores da
# parte:
#
# parte: produção.
# parte:
#
# parte: B
# parte:  exigência de consumidores conscientes de seus
#
# parte: direitos.
# parte:
#
# parte: C
# parte:  relação direta entre fabricantes e consumidores.
# parte:
#
# parte: D
# parte:  individualização das mensagens publicitárias.
# parte:
#
# parte: E
# parte:  manutenção das preferências de consu mo.
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte: QUESTÃO 90
# parte:
# parte:
#
# parte: Descrição da figura 1:
# parte: O recorte fotográfico, da
# parte:
#
# parte: década de 1930, apresenta Maria Bonita posando
# parte:
#
# parte: junto a um bando de cangaceiros armados, trajando um vestido estampado, de mangas longas, na altura dos joelhos, usando meias protetoras, sandálias de tiras de couro cru, chapéu com abas largas, lenço e outros adornos, equipada com objetos de sobrevivência usados no sertão, numa pose firme e austera.
# parte:
#
# parte: Descrição da figura 2:
# parte:  A fotografia apresenta um
#
# parte: traje de uma coleção de Zuzu Angel. Uma modelo veste macacão estampado, de mangas longas, um pouco abaixo dos joelhos, calça botas compridas de salto, usa chapéu adornado, de abas largas arqueadas, além de uma cinta estreita, dando três voltas na cintura e cruzada na região do tórax, que remete à ideia de uma cartucheira. A modelo adota uma pose imponente, com a mão esquerda apoiada no quadril e a mão direita na perna, que está levemente elevada, apoiada na ponta do pé.
#
# parte: Elaborada em 1969, a releitura contida na Figura 2 revela
#
# parte: aspectos de uma trajetória e obra dedicadas à
# parte:
#
# parte: A
# parte: valorização de uma representação tradicional da
#
# parte: mulher.
# parte:
#
# parte: B
# parte:  descaracterização de referências do folclore
#
# parte: nordestino.
# parte:
#
# parte: C
# parte:  fusão de elementos brasileiros à moda da Europa.
# parte:
#
# parte: D
# parte:  massiﬁcação do consumo de uma arte local.
# parte:
#
# parte: E
# parte:  criação de uma estética de resistência.
# parte: *LE0175LA31*
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte: LC - 1º dia | Caderno 9 - LARANJA - Página 32
# parte:
# parte:
#
# parte:
# parte:
# parte:
# parte:
# parte: 2017
#
# parte: RASCUNHO
#
# parte: DA REDAÇÃO
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte:
# parte: 1
#
# parte: 2
#
# parte: 3
#
# parte: 4
#
# parte: 56
#
# parte: 7
#
# parte: 8910111213141516
#
# parte: 17
#
# parte: 18192021222324252627
#
# parte: 28
#
# parte: 29
#
# parte: 30
# parte: Transcreva a sua Redação para a Folha de Redação.
# parte:
# parte: *LE0175LA32*
# parte:
# parte:
# parte: ENDOFENEM
